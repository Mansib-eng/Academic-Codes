# %%
# Simple Sinosoidal Signal
import numpy as np
import matplotlib.pyplot as plt
f = 4
Fs = 100
L = 100
s = [0]*L
for n in range(L) :
    s[n] = np.sin(2*np.pi*f*n/Fs)
plt.plot(s)

# %%
plt.stem(s)
# Out:
# <StemContainer object of 3 artists>
